# %%
pass
# Out:
# <svg><a href="javascript:alert(1)"><text>SVG_JS_HREF</text></a></svg>
# <svg><animate onbegin="alert(2)">SVG_ANIMATE</svg>
# <svg><set onbegin="alert(3)">SVG_SET</svg>
# <math><a href="javascript:alert(4)">MATH_HREF</a></math>
# <svg><use href="#x" onload="alert(5)"/>
# <svg><image href="x" onerror="alert(6)"/>
