# %%
pass
# Out:
# <svg><defs><symbol id="x"><a href="javascript:alert(1)"><text>CLICK_SVG_USE</text></a></symbol></defs><use href="#x"/></svg>
# <svg><defs><filter id="f"><feGaussianBlur stdDeviation="0"/></filter></defs><circle cx="50" cy="50" r="50" filter="url(#f)"/></svg>
# <svg><foreignObject width="100%" height="100%"><div xmlns="http://www.w3.org/1999/xhtml"><a href="javascript:alert(2)">FOREIGN_OBJ</a></div></foreignObject></svg>
